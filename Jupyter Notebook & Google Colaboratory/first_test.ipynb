# %% [markdown]
# ## _Isso é um texto em **Markdown**_

# %% [markdown]
# <h1>Isso é um texto em <b>HTML<b><h1>

# %%
print("Isto é uma linha de código em Python\n")
# Out:
# Isto é uma linha de código em Python

# %% [markdown]
# <a src="google.com">Clique aqui</a>
